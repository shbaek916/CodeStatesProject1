# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Codestates Project 1/raw_data/train.csv')

# %%
train.head()
# Out:
#    game_id  winner  time  ...  species      event                  event_contents
# 0        0       1  0.00  ...        T     Camera         at (145.25, 21.5078125)
# 1        0       1  0.00  ...        T     Camera         at (22.75, 147.0078125)
# 2        0       1  0.02  ...        T  Selection    ['OrbitalCommand [3080001]']
# 3        0       1  0.02  ...        T    Ability               (1360) - TrainSCV
# 4        0       1  0.14  ...        T     Camera  at (142.99609375, 24.50390625)
#
# [5 rows x 7 columns]

# %%
train10000 = train[train['game_id']<10001] # 17282265
train10000.to_csv('/content/drive/MyDrive/Colab Notebooks/Codestates Project 1/raw_data/train10000.csv',sep=',',index=False)
del train10000

# %%
train20000 = train[(train['game_id'] <20001) & (train['game_id'] >10000)] # 17172094
train20000.to_csv('/content/drive/MyDrive/Colab Notebooks/Codestates Project 1/raw_data/train20000.csv',sep=',',index=False)
del train20000

# %%
train30000 = train[(train['game_id'] <30001) & (train['game_id'] >20000)]
train30000.to_csv('/content/drive/MyDrive/Colab Notebooks/Codestates Project 1/raw_data/train30000.csv',sep=',',index=False)
del train30000

# %%
train38871 = train[train['game_id']> 30000]
train38871.to_csv('/content/drive/MyDrive/Colab Notebooks/Codestates Project 1/raw_data/train38871.csv',sep=',',index=False)
del train38871

# %%
train[(train['game_id'] <20001) & (train['game_id'] >10000)].head() # 17282265
# Out:
#           game_id  winner  ...      event                event_contents
# 17282265    10001       0  ...     Camera       at (151.25, 20.5078125)
# 17282266    10001       0  ...     Camera       at (24.75, 128.0078125)
# 17282267    10001       0  ...  Selection           ['Nexus [3440001]']
# 17282268    10001       0  ...  Selection  ['OrbitalCommand [3100001]']
# 17282269    10001       0  ...    Ability             (1360) - TrainSCV
#
# [5 rows x 7 columns]

# %%
len(train[(train['game_id'] <20001) & (train['game_id'] >10000)])
# Out:
# 17172094

# %%
del train

# %%
test =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Codestates Project 1/raw_data/test.csv')
test.shape
# Out:
# (28714849, 6)

# %%
test.tail()
# Out:
#           game_id  ...                                     event_contents
# 28714844    55658  ...  Location: (120.584228515625, 56.930419921875, ...
# 28714845    55658  ...                      at (70.9921875, 117.65234375)
# 28714846    55658  ...  Location: (122.146728515625, 55.52099609375, 3...
# 28714847    55658  ...       Location: (123.6767578125, 54.140625, 33215)
# 28714848    55658  ...  Location: (124.775634765625, 54.123779296875, ...
#
# [5 rows x 6 columns]
